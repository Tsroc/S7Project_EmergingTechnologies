# %% [markdown]
# #### Reading the wind speed file.

# %%
# info here: https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
# http://www.smartcomputerlab.org/m6/Lab1.regression.tf.keras.pdf

# %% [markdown]
# ## Imports

# %%
# Data frames.
import pandas as pd

# Plotting.
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning.
import keras as kr
import tensorflow as tf

import numpy as np

# %% [markdown]
# ## Class: Linear Regression

# %%
class LinearRegression:
    
    # Constructor, defining # of epochs here.
    def __init__(self, epoch):
        print(f'Linear Regression model to be created with {epoch} epochs.')
        self.epoch = epoch

    # Loads the data from the file, seperates into X and y.
    def LoadData(self, fname):  
        # Limiting to .3 decimal points.
        np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
        # Reading fname, skipping headings
        self.dataset = np.loadtxt(fname, delimiter=",", skiprows=1)
        # Windspeed data.
        self.X = self.dataset[:,0]
        # Power data.
        self.y = self.dataset[:,1]
        
    # Creates the model.
    def CreateModel(self):
        # Create model.
        from keras.models import Sequential
        from keras.layers import Dense

        thisShape = 1

        self.model = Sequential()
        self.model.add(Dense(12, input_dim=thisShape, activation='relu'))
        self.model.add(Dense(8, activation='relu'))
        self.model.add(Dense(thisShape, activation='relu'))

        # Train model.
        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
        self.model.compile(optimizer=optimizer, loss='mean_squared_error')
        self.tf_history = self.model.fit(self.X, self.y, epochs=self.epoch, verbose=True)
        
        # Prediction.
        self.predictions = self.model.predict(self.X)
        
    def PredictPower(self, windspeed):
        speed = [windspeed]
        prediction = self.model.predict(speed)
        print("Power prediction: %.3f" % prediction)
        
    # Displays the model loss.
    def DisplayLoss(self):
        # displayLoss():
        plt.title("Linear Regression")
        plt.plot(self.tf_history.history['loss'], color="red")
        plt.xlabel('Epochs')
        plt.ylabel('loss')
        plt.show()
        
    # Displays the model predictions.
    def DisplayPrediction(self):
        # displayPlot():
        plt.figure(figsize=(12,7))
        plt.title('Results')
        plt.scatter(self.X, self.y, label='Data $(X, y)$')
        plt.plot(self.X, self.predictions, color='red', label='Linear Regression',linewidth=3.0)
        plt.xlabel('$X$', fontsize=20)
        plt.ylabel('$y$', fontsize=20)
        plt.grid(True)
        plt.legend(fontsize=20)
        plt.show()

# %% [markdown]
# ## Class: Polynomial Regression

# %%
class PolynomialRegression:
    
    # Constructor, defining # of epochs and poly features here.
    def __init__(self, epoch, polyDegree):
        print(f'Polynomial Regression model to be created with {polyDegree} Polynominal features, {epoch} epochs.')
        # PolynomialFeatures.
        self.polyDegree = polyDegree
        self.epoch = epoch

    # Loads the data from the file, seperates into X and y. Allows for polynomial features.
    def LoadData(self, fname):  
        # Limiting to .3 decimal points.
        np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
        # Reading fname, skipping headings
        self.dataset = np.loadtxt(fname, delimiter=",", skiprows=1)
        # Windspeed data.
        self.X = self.dataset[:,0]
        # Power data.
        self.y = self.dataset[:,1]
        
        from sklearn.preprocessing import PolynomialFeatures
        self.poly = PolynomialFeatures(degree=self.polyDegree)
        self.X_2 = self.poly.fit_transform(self.X.reshape(-1,1))
        
    # Creates the model.
    def CreateModel(self):
        # Create model.
        from keras.models import Sequential
        from keras.layers import Dense

        thisShape = 1+self.polyDegree

        self.model = Sequential()
        self.model.add(Dense(64, input_dim=thisShape, activation='relu'))
        self.model.add(Dense(32, activation='relu'))
        self.model.add(Dense(thisShape, activation='relu'))

        # Train model.
        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
        self.model.compile(optimizer=optimizer, loss='mean_squared_error')
        self.pr_history = self.model.fit(self.X_2, self.y, epochs=self.epoch, verbose=True)
                
        # Prediction.
        self.predictions = self.model.predict(self.X_2)
        
    # Makes a prediction based on the model.
    def PredictPower(self, windspeed):
        value = np.array([windspeed])
        aValue = self.poly.fit_transform(value.reshape(-1,1))
        prediction = self.model.predict(aValue)
        print("Power prediction: %.3f" % prediction[0][1])
        
    # Displays the model loss.
    def DisplayLoss(self):
        plt.title("Polynomial Regression")
        plt.plot(self.pr_history.history['loss'], color="red")
        plt.xlabel('Epochs')
        plt.ylabel('loss')
        plt.show()
        
    # Displays the model predictions.
    def DisplayPrediction(self):
        plt.figure(figsize=(12,7))
        plt.title('Results')
        plt.scatter(self.X_2[:,1], self.y, label='Data $(X, y)$')
        plt.plot(self.X_2[:,1], self.predictions[:,1], color='orange', label='Polynomial Regression',linewidth=3.0)
        plt.xlabel('$X$', fontsize=20)
        plt.ylabel('$y$', fontsize=20)
        plt.grid(True)
        plt.legend(fontsize=20)
        plt.show()

# %% [markdown]
# ## Testing
# Testing the LinearRegression and PolynomialRegression models.

# %%
class TestClass:
    fname = "Windspeed.txt"
  
    
    def CreateLinearRegression(self):
        self.lr = LinearRegression(200)
        self.lr.LoadData(self.fname)

    def CreatePolynomialRegression(self):
        self.pr = PolynomialRegression(200, 3)
        self.pr.LoadData(self.fname)   
        
    def TrainLR(self):
        self.lr.CreateModel()
    
    def TrainPR(self):
        self.pr.CreateModel()
        
    def DisplayLoss(self):
        self.lr.DisplayLoss()
        self.pr.DisplayLoss()
        
    def Predictions(self):
        self.lr.PredictPower(20)
        self.pr.PredictPower(20)

    def DisplayPredictions(self):
        self.lr.DisplayPrediction()
        self.pr.DisplayPrediction()

# %%
test = TestClass()
test.CreateLinearRegression()
test.CreatePolynomialRegression()
# Out:
# Linear Regression model to be created with 200 epochs.
# Polynomial Regression model to be created with 3 Polynominal features, 200 epochs.

# %%
test.TrainLR()
# Out:
# Epoch 1/200
# 16/16 [==============================] - 0s 750us/step - loss: 3289.9678
# Epoch 2/200
# 16/16 [==============================] - 0s 689us/step - loss: 3103.2092
# Epoch 3/200
# 16/16 [==============================] - 0s 754us/step - loss: 2917.3672
# Epoch 4/200
# 16/16 [==============================] - 0s 752us/step - loss: 2719.4949
# Epoch 5/200
# 16/16 [==============================] - 0s 812us/step - loss: 2514.3271
# Epoch 6/200
# 16/16 [==============================] - 0s 813us/step - loss: 2305.8535
# Epoch 7/200
# 16/16 [==============================] - 0s 750us/step - loss: 2097.8157
# Epoch 8/200
# 16/16 [==============================] - 0s 624us/step - loss: 1896.3213
# Epoch 9/200
# 16/16 [==============================] - 0s 687us/step - loss: 1698.2357
# Epoch 10/200
# 16/16 [==============================] - 0s 750us/step - loss: 1504.3481
# Epoch 11/200
# 16/16 [==============================] - 0s 687us/step - loss: 1316.9066
# Epoch 12/200
# 16/16 [==============================] - 0s 563us/step - loss: 1148.7922
# Epoch 13/200
# 16/16 [==============================] - 0s 562us/step - loss: 982.9903
# Epoch 14/200
# 16/16 [==============================] - 0s 750us/step - loss: 836.0165
# Epoch 15/200
# 16/16 [==============================] - 0s 688us/step - loss: 715.5754
# Epoch 16/200
# 16/16 [==============================] - 0s 563us/step - loss: 609.9561
# Epoch 17/200
# 16/16 [==============================] - 0s 625us/step - loss: 527.7884
# Epoch 18/200
# 16/16 [==============================] - 0s 750us/step - loss: 465.9561
# Epoch 19/200
# 16/16 [==============================] - 0s 750us/step - loss: 418.9142
# Epoch 20/200
# 16/16 [==============================] - 0s 750us/step - loss: 387.1223
# Epoch 21/200
# 16/16 [==============================] - 0s 499us/step - loss: 364.6328
# Epoch 22/200
# 16/16 [==============================] - 0s 625us/step - loss: 350.8102
# Epoch 23/200
# 16/16 [==============================] - 0s 688us/step - loss: 341.5586
# Epoch 24/200
# 16/16 [==============================] - 0s 688us/step - loss: 335.6352
# Epoch 25/200
# 16/16 [==============================] - 0s 562us/step - loss: 332.5032
# Epoch 26/200
# 16/16 [==============================] - 0s 687us/step - loss: 330.5902
# Epoch 27/200
# 16/16 [==============================] - 0s 750us/step - loss: 329.5649
# Epoch 28/200
# 16/16 [==============================] - 0s 750us/step - loss: 328.7867
# Epoch 29/200
# 16/16 [==============================] - 0s 625us/step - loss: 328.2035
# Epoch 30/200
# 16/16 [==============================] - 0s 625us/step - loss: 327.5847
# Epoch 31/200
# 16/16 [==============================] - 0s 687us/step - loss: 326.9844
# Epoch 32/200
# 16/16 [==============================] - 0s 688us/step - loss: 326.4083
# Epoch 33/200
# 16/16 [==============================] - 0s 688us/step - loss: 325.8584
# Epoch 34/200
# 16/16 [==============================] - 0s 562us/step - loss: 325.2915
# Epoch 35/200
# 16/16 [==============================] - 0s 750us/step - loss: 324.5916
# Epoch 36/200
# 16/16 [==============================] - 0s 750us/step - loss: 323.9684
# Epoch 37/200
# 16/16 [==============================] - 0s 625us/step - loss: 323.2901
# Epoch 38/200
# 16/16 [==============================] - 0s 562us/step - loss: 322.7132
# Epoch 39/200
# 16/16 [==============================] - 0s 687us/step - loss: 322.1074
# Epoch 40/200
# 16/16 [==============================] - 0s 750us/step - loss: 321.4417
# Epoch 41/200
# 16/16 [==============================] - 0s 625us/step - loss: 320.8901
# Epoch 42/200
# 16/16 [==============================] - ETA: 0s - loss: 312.755 - 0s 562us/step - loss: 320.2606
# Epoch 43/200
# 16/16 [==============================] - 0s 625us/step - loss: 319.5594
# Epoch 44/200
# 16/16 [==============================] - 0s 750us/step - loss: 318.9214
# Epoch 45/200
# 16/16 [==============================] - 0s 624us/step - loss: 318.2322
# Epoch 46/200
# 16/16 [==============================] - 0s 500us/step - loss: 317.7854
# Epoch 47/200
# 16/16 [==============================] - 0s 562us/step - loss: 317.0353
# Epoch 48/200
# 16/16 [==============================] - 0s 687us/step - loss: 316.4091
# Epoch 49/200
# 16/16 [==============================] - 0s 688us/step - loss: 315.7835
# Epoch 50/200
# 16/16 [==============================] - 0s 500us/step - loss: 314.9612
# Epoch 51/200
# 16/16 [==============================] - 0s 625us/step - loss: 314.4989
# Epoch 52/200
# 16/16 [==============================] - 0s 687us/step - loss: 314.0950
# Epoch 53/200
# 16/16 [==============================] - ETA: 0s - loss: 272.697 - 0s 688us/step - loss: 313.3643
# Epoch 54/200
# 16/16 [==============================] - 0s 688us/step - loss: 312.3753
# Epoch 55/200
# 16/16 [==============================] - 0s 500us/step - loss: 311.6569
# Epoch 56/200
# 16/16 [==============================] - 0s 750us/step - loss: 311.0024
# Epoch 57/200
# 16/16 [==============================] - 0s 625us/step - loss: 310.4520
# Epoch 58/200
# 16/16 [==============================] - 0s 562us/step - loss: 309.5208
# Epoch 59/200
# 16/16 [==============================] - 0s 687us/step - loss: 308.8741
# Epoch 60/200
# 16/16 [==============================] - 0s 812us/step - loss: 308.5138
# Epoch 61/200
# 16/16 [==============================] - 0s 687us/step - loss: 307.6877
# Epoch 62/200
# 16/16 [==============================] - 0s 687us/step - loss: 307.8485
# Epoch 63/200
# 16/16 [==============================] - 0s 562us/step - loss: 306.3497
# Epoch 64/200
# 16/16 [==============================] - 0s 500us/step - loss: 305.7097
# Epoch 65/200
# 16/16 [==============================] - 0s 750us/step - loss: 305.0711
# Epoch 66/200
# 16/16 [==============================] - 0s 750us/step - loss: 304.3135
# Epoch 67/200
# 16/16 [==============================] - 0s 500us/step - loss: 303.6729
# Epoch 68/200
# 16/16 [==============================] - 0s 625us/step - loss: 302.9774
# Epoch 69/200
# 16/16 [==============================] - 0s 687us/step - loss: 302.5200
# Epoch 70/200
# 16/16 [==============================] - 0s 750us/step - loss: 301.5661
# Epoch 71/200
# 16/16 [==============================] - 0s 750us/step - loss: 301.0414
# Epoch 72/200
# 16/16 [==============================] - 0s 625us/step - loss: 300.2781
# Epoch 73/200
# 16/16 [==============================] - 0s 688us/step - loss: 299.6256
# Epoch 74/200
# 16/16 [==============================] - 0s 812us/step - loss: 298.8554
# Epoch 75/200
# 16/16 [==============================] - 0s 813us/step - loss: 298.5099
# Epoch 76/200
# 16/16 [==============================] - 0s 687us/step - loss: 297.5476
# Epoch 77/200
# 16/16 [==============================] - 0s 500us/step - loss: 296.8115
# Epoch 78/200
# 16/16 [==============================] - 0s 688us/step - loss: 296.1028
# Epoch 79/200
# 16/16 [==============================] - 0s 687us/step - loss: 295.4183
# Epoch 80/200
# 16/16 [==============================] - 0s 750us/step - loss: 295.0267
# Epoch 81/200
# 16/16 [==============================] - 0s 750us/step - loss: 294.4884
# Epoch 82/200
# 16/16 [==============================] - 0s 688us/step - loss: 293.9255
# Epoch 83/200
# 16/16 [==============================] - 0s 500us/step - loss: 292.7691
# Epoch 84/200
# 16/16 [==============================] - 0s 625us/step - loss: 292.0418
# Epoch 85/200
# 16/16 [==============================] - 0s 688us/step - loss: 291.5980
# Epoch 86/200
# 16/16 [==============================] - 0s 750us/step - loss: 290.6171
# Epoch 87/200
# 16/16 [==============================] - 0s 562us/step - loss: 289.9415
# Epoch 88/200
# 16/16 [==============================] - 0s 687us/step - loss: 289.4702
# Epoch 89/200
# 16/16 [==============================] - 0s 750us/step - loss: 288.2805
# Epoch 90/200
# 16/16 [==============================] - 0s 813us/step - loss: 288.3475
# Epoch 91/200
# 16/16 [==============================] - 0s 813us/step - loss: 287.3175
# Epoch 92/200
# 16/16 [==============================] - 0s 813us/step - loss: 287.3154
# Epoch 93/200
# 16/16 [==============================] - 0s 562us/step - loss: 285.8286
# Epoch 94/200
# 16/16 [==============================] - 0s 625us/step - loss: 285.7704
# Epoch 95/200
# 16/16 [==============================] - 0s 750us/step - loss: 285.5556
# Epoch 96/200
# 16/16 [==============================] - 0s 750us/step - loss: 285.1604
# Epoch 97/200
# 16/16 [==============================] - 0s 750us/step - loss: 283.7603
# Epoch 98/200
# 16/16 [==============================] - 0s 875us/step - loss: 282.8485
# Epoch 99/200
# 16/16 [==============================] - 0s 750us/step - loss: 282.1866
# Epoch 100/200
# 16/16 [==============================] - 0s 750us/step - loss: 281.6042
# Epoch 101/200
# 16/16 [==============================] - 0s 562us/step - loss: 280.8687
# Epoch 102/200
# 16/16 [==============================] - 0s 625us/step - loss: 280.3050
# Epoch 103/200
# 16/16 [==============================] - 0s 750us/step - loss: 279.4651
# Epoch 104/200
# 16/16 [==============================] - 0s 687us/step - loss: 278.7836
# Epoch 105/200
# 16/16 [==============================] - 0s 750us/step - loss: 278.2795
# Epoch 106/200
# 16/16 [==============================] - 0s 500us/step - loss: 277.5479
# Epoch 107/200
# 16/16 [==============================] - 0s 562us/step - loss: 276.8123
# Epoch 108/200
# 16/16 [==============================] - 0s 625us/step - loss: 276.1598
# Epoch 109/200
# 16/16 [==============================] - 0s 750us/step - loss: 275.9406
# Epoch 110/200
# 16/16 [==============================] - 0s 625us/step - loss: 275.1527
# Epoch 111/200
# 16/16 [==============================] - 0s 687us/step - loss: 274.7600
# Epoch 112/200
# 16/16 [==============================] - 0s 812us/step - loss: 273.4861
# Epoch 113/200
# 16/16 [==============================] - 0s 750us/step - loss: 273.1634
# Epoch 114/200
# 16/16 [==============================] - 0s 813us/step - loss: 272.1423
# Epoch 115/200
# 16/16 [==============================] - 0s 750us/step - loss: 271.5354
# Epoch 116/200
# 16/16 [==============================] - 0s 562us/step - loss: 270.7906
# Epoch 117/200
# 16/16 [==============================] - 0s 562us/step - loss: 270.0340
# Epoch 118/200
# 16/16 [==============================] - 0s 687us/step - loss: 269.4764
# Epoch 119/200
# 16/16 [==============================] - 0s 625us/step - loss: 268.7866
# Epoch 120/200
# 16/16 [==============================] - 0s 500us/step - loss: 267.9798
# Epoch 121/200
# 16/16 [==============================] - 0s 687us/step - loss: 267.4872
# Epoch 122/200
# 16/16 [==============================] - 0s 625us/step - loss: 266.6944
# Epoch 123/200
# 16/16 [==============================] - 0s 562us/step - loss: 266.1807
# Epoch 124/200
# 16/16 [==============================] - 0s 562us/step - loss: 265.4648
# Epoch 125/200
# 16/16 [==============================] - 0s 625us/step - loss: 264.6820
# Epoch 126/200
# 16/16 [==============================] - 0s 563us/step - loss: 263.9657
# Epoch 127/200
# 16/16 [==============================] - 0s 562us/step - loss: 263.3540
# Epoch 128/200
# 16/16 [==============================] - 0s 687us/step - loss: 263.3640
# Epoch 129/200
# 16/16 [==============================] - 0s 688us/step - loss: 262.5528
# Epoch 130/200
# 16/16 [==============================] - 0s 500us/step - loss: 261.4955
# Epoch 131/200
# 16/16 [==============================] - 0s 625us/step - loss: 260.6475
# Epoch 132/200
# 16/16 [==============================] - 0s 687us/step - loss: 260.0183
# Epoch 133/200
# 16/16 [==============================] - 0s 562us/step - loss: 259.6622
# Epoch 134/200
# 16/16 [==============================] - 0s 625us/step - loss: 259.5761
# Epoch 135/200
# 16/16 [==============================] - 0s 750us/step - loss: 259.0382
# Epoch 136/200
# 16/16 [==============================] - 0s 688us/step - loss: 257.9542
# Epoch 137/200
# 16/16 [==============================] - 0s 562us/step - loss: 257.1353
# Epoch 138/200
# 16/16 [==============================] - 0s 625us/step - loss: 256.6220
# Epoch 139/200
# 16/16 [==============================] - 0s 687us/step - loss: 255.6745
# Epoch 140/200
# 16/16 [==============================] - 0s 687us/step - loss: 255.2144
# Epoch 141/200
# 16/16 [==============================] - 0s 688us/step - loss: 254.4878
# Epoch 142/200
# 16/16 [==============================] - 0s 562us/step - loss: 253.8792
# Epoch 143/200
# 16/16 [==============================] - 0s 688us/step - loss: 253.3174
# Epoch 144/200
# 16/16 [==============================] - 0s 688us/step - loss: 252.8743
# Epoch 145/200
# 16/16 [==============================] - 0s 563us/step - loss: 251.9972
# Epoch 146/200
# 16/16 [==============================] - 0s 562us/step - loss: 251.4388
# Epoch 147/200
# 16/16 [==============================] - 0s 687us/step - loss: 251.1189
# Epoch 148/200
# 16/16 [==============================] - 0s 563us/step - loss: 250.1944
# Epoch 149/200
# 16/16 [==============================] - 0s 562us/step - loss: 249.8804
# Epoch 150/200
# 16/16 [==============================] - 0s 688us/step - loss: 248.8082
# Epoch 151/200
# 16/16 [==============================] - 0s 625us/step - loss: 249.1496
# Epoch 152/200
# 16/16 [==============================] - 0s 562us/step - loss: 248.0814
# Epoch 153/200
# 16/16 [==============================] - 0s 625us/step - loss: 247.2204
# Epoch 154/200
# 16/16 [==============================] - 0s 687us/step - loss: 246.2644
# Epoch 155/200
# 16/16 [==============================] - ETA: 0s - loss: 206.087 - 0s 625us/step - loss: 245.7291
# Epoch 156/200
# 16/16 [==============================] - 0s 562us/step - loss: 245.3008
# Epoch 157/200
# 16/16 [==============================] - 0s 625us/step - loss: 244.7790
# Epoch 158/200
# 16/16 [==============================] - 0s 687us/step - loss: 243.8116
# Epoch 159/200
# 16/16 [==============================] - 0s 813us/step - loss: 243.2128
# Epoch 160/200
# 16/16 [==============================] - 0s 875us/step - loss: 242.7432
# Epoch 161/200
# 16/16 [==============================] - 0s 750us/step - loss: 242.0292
# Epoch 162/200
# 16/16 [==============================] - 0s 500us/step - loss: 241.8150
# Epoch 163/200
# 16/16 [==============================] - 0s 625us/step - loss: 240.8668
# Epoch 164/200
# 16/16 [==============================] - 0s 625us/step - loss: 240.0656
# Epoch 165/200
# 16/16 [==============================] - 0s 688us/step - loss: 239.7349
# Epoch 166/200
# 16/16 [==============================] - 0s 562us/step - loss: 239.1290
# Epoch 167/200
# 16/16 [==============================] - 0s 750us/step - loss: 238.5134
# Epoch 168/200
# 16/16 [==============================] - 0s 625us/step - loss: 238.0850
# Epoch 169/200
# 16/16 [==============================] - 0s 625us/step - loss: 237.3746
# Epoch 170/200
# 16/16 [==============================] - 0s 625us/step - loss: 236.9886
# Epoch 171/200
# 16/16 [==============================] - 0s 625us/step - loss: 236.0192
# Epoch 172/200
# 16/16 [==============================] - 0s 625us/step - loss: 235.3791
# Epoch 173/200
# 16/16 [==============================] - 0s 563us/step - loss: 234.7340
# Epoch 174/200
# 16/16 [==============================] - 0s 687us/step - loss: 234.0362
# Epoch 175/200
# 16/16 [==============================] - 0s 625us/step - loss: 233.4831
# Epoch 176/200
# 16/16 [==============================] - 0s 500us/step - loss: 233.7016
# Epoch 177/200
# 16/16 [==============================] - 0s 562us/step - loss: 232.5038
# Epoch 178/200
# 16/16 [==============================] - 0s 687us/step - loss: 231.9303
# Epoch 179/200
# 16/16 [==============================] - 0s 813us/step - loss: 231.4115
# Epoch 180/200
# 16/16 [==============================] - 0s 750us/step - loss: 231.1889
# Epoch 181/200
# 16/16 [==============================] - 0s 563us/step - loss: 230.2423
# Epoch 182/200
# 16/16 [==============================] - 0s 812us/step - loss: 229.9408
# Epoch 183/200
# 16/16 [==============================] - 0s 812us/step - loss: 229.4392
# Epoch 184/200
# 16/16 [==============================] - 0s 813us/step - loss: 228.4061
# Epoch 185/200
# 16/16 [==============================] - 0s 814us/step - loss: 228.1635
# Epoch 186/200
# 16/16 [==============================] - 0s 687us/step - loss: 227.4350
# Epoch 187/200
# 16/16 [==============================] - 0s 500us/step - loss: 226.8049
# Epoch 188/200
# 16/16 [==============================] - 0s 687us/step - loss: 226.1613
# Epoch 189/200
# 16/16 [==============================] - 0s 750us/step - loss: 225.6457
# Epoch 190/200
# 16/16 [==============================] - 0s 687us/step - loss: 225.0060
# Epoch 191/200
# 16/16 [==============================] - 0s 563us/step - loss: 224.5084
# Epoch 192/200
# 16/16 [==============================] - 0s 625us/step - loss: 224.1565
# Epoch 193/200
# 16/16 [==============================] - 0s 750us/step - loss: 223.8055
# Epoch 194/200
# 16/16 [==============================] - 0s 625us/step - loss: 222.8970
# Epoch 195/200
# 16/16 [==============================] - 0s 500us/step - loss: 222.6476
# Epoch 196/200
# 16/16 [==============================] - 0s 562us/step - loss: 221.9577
# Epoch 197/200
# 16/16 [==============================] - 0s 687us/step - loss: 221.6225
# Epoch 198/200
# 16/16 [==============================] - 0s 625us/step - loss: 220.9918
# Epoch 199/200
# 16/16 [==============================] - 0s 500us/step - loss: 220.3539
# Epoch 200/200
# 16/16 [==============================] - 0s 687us/step - loss: 219.7034

# %%
test.TrainPR()
# Out:
# Epoch 1/200
# 16/16 [==============================] - 0s 750us/step - loss: 3772.4021
# Epoch 2/200
# 16/16 [==============================] - 0s 875us/step - loss: 3240.6409
# Epoch 3/200
# 16/16 [==============================] - 0s 812us/step - loss: 3282.0610
# Epoch 4/200
# 16/16 [==============================] - 0s 875us/step - loss: 2693.0535
# Epoch 5/200
# 16/16 [==============================] - 0s 875us/step - loss: 1988.9272
# Epoch 6/200
# 16/16 [==============================] - 0s 876us/step - loss: 2077.9507
# Epoch 7/200
# 16/16 [==============================] - 0s 812us/step - loss: 1557.2938
# Epoch 8/200
# 16/16 [==============================] - 0s 813us/step - loss: 1418.0050
# Epoch 9/200
# 16/16 [==============================] - 0s 750us/step - loss: 1414.4634
# Epoch 10/200
# 16/16 [==============================] - 0s 562us/step - loss: 1423.8866
# Epoch 11/200
# 16/16 [==============================] - 0s 687us/step - loss: 1466.4049
# Epoch 12/200
# 16/16 [==============================] - 0s 750us/step - loss: 1618.7681
# Epoch 13/200
# 16/16 [==============================] - 0s 750us/step - loss: 1321.1129
# Epoch 14/200
# 16/16 [==============================] - 0s 750us/step - loss: 1316.7013
# Epoch 15/200
# 16/16 [==============================] - 0s 624us/step - loss: 1364.1953
# Epoch 16/200
# 16/16 [==============================] - 0s 750us/step - loss: 1309.3495
# Epoch 17/200
# 16/16 [==============================] - 0s 687us/step - loss: 1352.8894
# Epoch 18/200
# 16/16 [==============================] - 0s 750us/step - loss: 1291.0065
# Epoch 19/200
# 16/16 [==============================] - 0s 750us/step - loss: 1354.8593
# Epoch 20/200
# 16/16 [==============================] - 0s 625us/step - loss: 1270.8885
# Epoch 21/200
# 16/16 [==============================] - 0s 687us/step - loss: 1211.4003
# Epoch 22/200
# 16/16 [==============================] - 0s 750us/step - loss: 1216.2927
# Epoch 23/200
# 16/16 [==============================] - 0s 812us/step - loss: 1231.2185
# Epoch 24/200
# 16/16 [==============================] - 0s 812us/step - loss: 1210.3441
# Epoch 25/200
# 16/16 [==============================] - 0s 688us/step - loss: 1226.4727
# Epoch 26/200
# 16/16 [==============================] - 0s 562us/step - loss: 1192.1245
# Epoch 27/200
# 16/16 [==============================] - 0s 687us/step - loss: 1185.1047
# Epoch 28/200
# 16/16 [==============================] - 0s 812us/step - loss: 1185.8942
# Epoch 29/200
# 16/16 [==============================] - 0s 750us/step - loss: 1198.7954
# Epoch 30/200
# 16/16 [==============================] - 0s 813us/step - loss: 1206.9980
# Epoch 31/200
# 16/16 [==============================] - 0s 750us/step - loss: 1186.5702
# Epoch 32/200
# 16/16 [==============================] - 0s 625us/step - loss: 1205.8319
# Epoch 33/200
# 16/16 [==============================] - 0s 625us/step - loss: 1194.5322
# Epoch 34/200
# 16/16 [==============================] - 0s 750us/step - loss: 1209.4297
# Epoch 35/200
# 16/16 [==============================] - 0s 750us/step - loss: 1241.6084
# Epoch 36/200
# 16/16 [==============================] - 0s 813us/step - loss: 1178.8308
# Epoch 37/200
# 16/16 [==============================] - 0s 750us/step - loss: 1216.8162
# Epoch 38/200
# 16/16 [==============================] - 0s 625us/step - loss: 1212.7487
# Epoch 39/200
# 16/16 [==============================] - 0s 687us/step - loss: 1227.1348
# Epoch 40/200
# 16/16 [==============================] - 0s 750us/step - loss: 1174.5424
# Epoch 41/200
# 16/16 [==============================] - 0s 750us/step - loss: 1179.4575
# Epoch 42/200
# 16/16 [==============================] - 0s 813us/step - loss: 1190.8364
# Epoch 43/200
# 16/16 [==============================] - 0s 625us/step - loss: 1177.0316
# Epoch 44/200
# 16/16 [==============================] - 0s 562us/step - loss: 1170.6521
# Epoch 45/200
# 16/16 [==============================] - 0s 750us/step - loss: 1172.2611
# Epoch 46/200
# 16/16 [==============================] - 0s 750us/step - loss: 1168.0387
# Epoch 47/200
# 16/16 [==============================] - 0s 687us/step - loss: 1209.9487
# Epoch 48/200
# 16/16 [==============================] - 0s 688us/step - loss: 1200.4895
# Epoch 49/200
# 16/16 [==============================] - 0s 625us/step - loss: 1224.1122
# Epoch 50/200
# 16/16 [==============================] - 0s 687us/step - loss: 1268.5402
# Epoch 51/200
# 16/16 [==============================] - 0s 750us/step - loss: 1366.9554
# Epoch 52/200
# 16/16 [==============================] - 0s 814us/step - loss: 1535.6448
# Epoch 53/200
# 16/16 [==============================] - 0s 750us/step - loss: 1408.5044
# Epoch 54/200
# 16/16 [==============================] - 0s 875us/step - loss: 1338.9893
# Epoch 55/200
# 16/16 [==============================] - 0s 688us/step - loss: 1248.6313
# Epoch 56/200
# 16/16 [==============================] - 0s 875us/step - loss: 1205.5364
# Epoch 57/200
# 16/16 [==============================] - 0s 562us/step - loss: 1168.5657
# Epoch 58/200
# 16/16 [==============================] - 0s 687us/step - loss: 1226.3137
# Epoch 59/200
# 16/16 [==============================] - 0s 750us/step - loss: 1182.0897
# Epoch 60/200
# 16/16 [==============================] - 0s 687us/step - loss: 1200.3264
# Epoch 61/200
# 16/16 [==============================] - 0s 750us/step - loss: 1200.4952
# Epoch 62/200
# 16/16 [==============================] - 0s 625us/step - loss: 1191.0137
# Epoch 63/200
# 16/16 [==============================] - 0s 625us/step - loss: 1161.5800
# Epoch 64/200
# 16/16 [==============================] - 0s 687us/step - loss: 1198.9874
# Epoch 65/200
# 16/16 [==============================] - 0s 750us/step - loss: 1220.7371
# Epoch 66/200
# 16/16 [==============================] - 0s 625us/step - loss: 1170.3960
# Epoch 67/200
# 16/16 [==============================] - 0s 625us/step - loss: 1148.7130
# Epoch 68/200
# 16/16 [==============================] - 0s 687us/step - loss: 1152.8845
# Epoch 69/200
# 16/16 [==============================] - 0s 687us/step - loss: 1166.4552
# Epoch 70/200
# 16/16 [==============================] - 0s 687us/step - loss: 1154.9540
# Epoch 71/200
# 16/16 [==============================] - 0s 562us/step - loss: 1136.3939
# Epoch 72/200
# 16/16 [==============================] - 0s 625us/step - loss: 1150.6371
# Epoch 73/200
# 16/16 [==============================] - 0s 812us/step - loss: 1167.9385
# Epoch 74/200
# 16/16 [==============================] - 0s 750us/step - loss: 1179.3370
# Epoch 75/200
# 16/16 [==============================] - 0s 812us/step - loss: 1141.1860
# Epoch 76/200
# 16/16 [==============================] - 0s 750us/step - loss: 1140.7051
# Epoch 77/200
# 16/16 [==============================] - 0s 625us/step - loss: 1140.7744
# Epoch 78/200
# 16/16 [==============================] - 0s 625us/step - loss: 1144.3552
# Epoch 79/200
# 16/16 [==============================] - 0s 750us/step - loss: 1146.7601
# Epoch 80/200
# 16/16 [==============================] - 0s 750us/step - loss: 1132.5023
# Epoch 81/200
# 16/16 [==============================] - 0s 625us/step - loss: 1135.6418
# Epoch 82/200
# 16/16 [==============================] - 0s 625us/step - loss: 1154.8247
# Epoch 83/200
# 16/16 [==============================] - 0s 750us/step - loss: 1236.2955
# Epoch 84/200
# 16/16 [==============================] - 0s 688us/step - loss: 1176.1268
# Epoch 85/200
# 16/16 [==============================] - 0s 750us/step - loss: 1151.6365
# Epoch 86/200
# 16/16 [==============================] - 0s 625us/step - loss: 1122.4351
# Epoch 87/200
# 16/16 [==============================] - 0s 562us/step - loss: 1142.0315
# Epoch 88/200
# 16/16 [==============================] - 0s 750us/step - loss: 1387.0874
# Epoch 89/200
# 16/16 [==============================] - 0s 687us/step - loss: 1142.9915
# Epoch 90/200
# 16/16 [==============================] - 0s 813us/step - loss: 1136.6547
# Epoch 91/200
# 16/16 [==============================] - 0s 813us/step - loss: 1497.8969
# Epoch 92/200
# 16/16 [==============================] - 0s 750us/step - loss: 1279.1793
# Epoch 93/200
# 16/16 [==============================] - 0s 875us/step - loss: 1119.3624
# Epoch 94/200
# 16/16 [==============================] - 0s 562us/step - loss: 1111.2390
# Epoch 95/200
# 16/16 [==============================] - 0s 812us/step - loss: 1123.7559
# Epoch 96/200
# 16/16 [==============================] - 0s 625us/step - loss: 1173.9490
# Epoch 97/200
# 16/16 [==============================] - 0s 812us/step - loss: 1147.5068
# Epoch 98/200
# 16/16 [==============================] - 0s 750us/step - loss: 1117.5603
# Epoch 99/200
# 16/16 [==============================] - 0s 938us/step - loss: 1103.3492
# Epoch 100/200
# 16/16 [==============================] - 0s 813us/step - loss: 1103.5483
# Epoch 101/200
# 16/16 [==============================] - 0s 750us/step - loss: 1110.1934
# Epoch 102/200
# 16/16 [==============================] - 0s 750us/step - loss: 1112.3436
# Epoch 103/200
# 16/16 [==============================] - 0s 812us/step - loss: 1106.3700
# Epoch 104/200
# 16/16 [==============================] - 0s 500us/step - loss: 1115.4457
# Epoch 105/200
# 16/16 [==============================] - 0s 750us/step - loss: 1140.9945
# Epoch 106/200
# 16/16 [==============================] - 0s 750us/step - loss: 1121.6624
# Epoch 107/200
# 16/16 [==============================] - 0s 812us/step - loss: 1173.7844
# Epoch 108/200
# 16/16 [==============================] - 0s 875us/step - loss: 1298.4913
# Epoch 109/200
# 16/16 [==============================] - 0s 812us/step - loss: 1135.8267
# Epoch 110/200
# 16/16 [==============================] - 0s 875us/step - loss: 1127.7007
# Epoch 111/200
# 16/16 [==============================] - 0s 813us/step - loss: 1107.4852
# Epoch 112/200
# 16/16 [==============================] - 0s 813us/step - loss: 1106.8868
# Epoch 113/200
# 16/16 [==============================] - 0s 1ms/step - loss: 1101.0886
# Epoch 114/200
# 16/16 [==============================] - 0s 1000us/step - loss: 1116.0303
# Epoch 115/200
# 16/16 [==============================] - 0s 812us/step - loss: 1111.7378
# Epoch 116/200
# 16/16 [==============================] - 0s 812us/step - loss: 1104.1432
# Epoch 117/200
# 16/16 [==============================] - 0s 625us/step - loss: 1100.2662
# Epoch 118/200
# 16/16 [==============================] - 0s 625us/step - loss: 1098.2405
# Epoch 119/200
# 16/16 [==============================] - 0s 750us/step - loss: 1146.7979
# Epoch 120/200
# 16/16 [==============================] - 0s 812us/step - loss: 1144.3885
# Epoch 121/200
# 16/16 [==============================] - 0s 875us/step - loss: 1117.6359
# Epoch 122/200
# 16/16 [==============================] - 0s 813us/step - loss: 1113.7708
# Epoch 123/200
# 16/16 [==============================] - 0s 750us/step - loss: 1140.3467
# Epoch 124/200
# 16/16 [==============================] - 0s 625us/step - loss: 1126.4941
# Epoch 125/200
# 16/16 [==============================] - 0s 813us/step - loss: 1103.5977
# Epoch 126/200
# 16/16 [==============================] - 0s 812us/step - loss: 1166.6577
# Epoch 127/200
# 16/16 [==============================] - 0s 937us/step - loss: 1183.6835
# Epoch 128/200
# 16/16 [==============================] - 0s 1ms/step - loss: 1158.9319
# Epoch 129/200
# 16/16 [==============================] - 0s 938us/step - loss: 1230.4771
# Epoch 130/200
# 16/16 [==============================] - 0s 1ms/step - loss: 1123.7955
# Epoch 131/200
# 16/16 [==============================] - 0s 1000us/step - loss: 1150.4762
# Epoch 132/200
# 16/16 [==============================] - 0s 1000us/step - loss: 1174.0223
# Epoch 133/200
# 16/16 [==============================] - 0s 1000us/step - loss: 1215.9392
# Epoch 134/200
# 16/16 [==============================] - 0s 875us/step - loss: 1160.1003
# Epoch 135/200
# 16/16 [==============================] - 0s 812us/step - loss: 1166.0734
# Epoch 136/200
# 16/16 [==============================] - 0s 687us/step - loss: 1120.8770
# Epoch 137/200
# 16/16 [==============================] - 0s 687us/step - loss: 1262.1514
# Epoch 138/200
# 16/16 [==============================] - 0s 750us/step - loss: 1151.6089
# Epoch 139/200
# 16/16 [==============================] - 0s 562us/step - loss: 1123.7192
# Epoch 140/200
# 16/16 [==============================] - 0s 750us/step - loss: 1109.7994
# Epoch 141/200
# 16/16 [==============================] - 0s 813us/step - loss: 1135.3038
# Epoch 142/200
# 16/16 [==============================] - 0s 812us/step - loss: 1119.8666
# Epoch 143/200
# 16/16 [==============================] - 0s 813us/step - loss: 1183.6998
# Epoch 144/200
# 16/16 [==============================] - 0s 938us/step - loss: 1133.4198
# Epoch 145/200
# 16/16 [==============================] - 0s 813us/step - loss: 1112.8313
# Epoch 146/200
# 16/16 [==============================] - 0s 750us/step - loss: 1113.1993
# Epoch 147/200
# 16/16 [==============================] - 0s 625us/step - loss: 1126.3085
# Epoch 148/200
# 16/16 [==============================] - 0s 750us/step - loss: 1126.9373
# Epoch 149/200
# 16/16 [==============================] - 0s 750us/step - loss: 1109.6398
# Epoch 150/200
# 16/16 [==============================] - 0s 750us/step - loss: 1120.1460
# Epoch 151/200
# 16/16 [==============================] - 0s 750us/step - loss: 1155.3477
# Epoch 152/200
# 16/16 [==============================] - 0s 750us/step - loss: 1186.7426
# Epoch 153/200
# 16/16 [==============================] - 0s 562us/step - loss: 1142.7317
# Epoch 154/200
# 16/16 [==============================] - 0s 625us/step - loss: 1110.6975
# Epoch 155/200
# 16/16 [==============================] - 0s 750us/step - loss: 1110.3434
# Epoch 156/200
# 16/16 [==============================] - 0s 750us/step - loss: 1154.4972
# Epoch 157/200
# 16/16 [==============================] - 0s 688us/step - loss: 1112.4037
# Epoch 158/200
# 16/16 [==============================] - 0s 687us/step - loss: 1125.9739
# Epoch 159/200
# 16/16 [==============================] - 0s 562us/step - loss: 1120.8668
# Epoch 160/200
# 16/16 [==============================] - 0s 750us/step - loss: 1137.3649
# Epoch 161/200
# 16/16 [==============================] - 0s 687us/step - loss: 1250.8160
# Epoch 162/200
# 16/16 [==============================] - 0s 750us/step - loss: 1499.7061
# Epoch 163/200
# 16/16 [==============================] - 0s 687us/step - loss: 1507.0907
# Epoch 164/200
# 16/16 [==============================] - 0s 875us/step - loss: 1208.4475
# Epoch 165/200
# 16/16 [==============================] - 0s 625us/step - loss: 1243.2948
# Epoch 166/200
# 16/16 [==============================] - 0s 812us/step - loss: 1183.3882
# Epoch 167/200
# 16/16 [==============================] - 0s 750us/step - loss: 1161.7609
# Epoch 168/200
# 16/16 [==============================] - 0s 687us/step - loss: 1135.2642
# Epoch 169/200
# 16/16 [==============================] - 0s 750us/step - loss: 1103.7980
# Epoch 170/200
# 16/16 [==============================] - 0s 750us/step - loss: 1136.2906
# Epoch 171/200
# 16/16 [==============================] - 0s 562us/step - loss: 1142.8448
# Epoch 172/200
# 16/16 [==============================] - 0s 813us/step - loss: 1136.4779
# Epoch 173/200
# 16/16 [==============================] - 0s 687us/step - loss: 1148.9563
# Epoch 174/200
# 16/16 [==============================] - 0s 750us/step - loss: 1137.5261
# Epoch 175/200
# 16/16 [==============================] - 0s 625us/step - loss: 1131.6112
# Epoch 176/200
# 16/16 [==============================] - 0s 625us/step - loss: 1133.4940
# Epoch 177/200
# 16/16 [==============================] - 0s 687us/step - loss: 1110.9583
# Epoch 178/200
# 16/16 [==============================] - 0s 813us/step - loss: 1106.8783
# Epoch 179/200
# 16/16 [==============================] - 0s 875us/step - loss: 1118.1924
# Epoch 180/200
# 16/16 [==============================] - 0s 875us/step - loss: 1113.0231
# Epoch 181/200
# 16/16 [==============================] - 0s 875us/step - loss: 1117.9003
# Epoch 182/200
# 16/16 [==============================] - 0s 812us/step - loss: 1150.8041
# Epoch 183/200
# 16/16 [==============================] - 0s 875us/step - loss: 1327.4388
# Epoch 184/200
# 16/16 [==============================] - 0s 875us/step - loss: 1246.0765
# Epoch 185/200
# 16/16 [==============================] - 0s 875us/step - loss: 1149.3752
# Epoch 186/200
# 16/16 [==============================] - 0s 813us/step - loss: 1162.1356
# Epoch 187/200
# 16/16 [==============================] - ETA: 0s - loss: 716.560 - 0s 688us/step - loss: 1139.9215
# Epoch 188/200
# 16/16 [==============================] - 0s 625us/step - loss: 1138.7026
# Epoch 189/200
# 16/16 [==============================] - 0s 687us/step - loss: 1110.0271
# Epoch 190/200
# 16/16 [==============================] - 0s 812us/step - loss: 1129.1219
# Epoch 191/200
# 16/16 [==============================] - 0s 812us/step - loss: 1108.6191
# Epoch 192/200
# 16/16 [==============================] - 0s 750us/step - loss: 1151.3872
# Epoch 193/200
# 16/16 [==============================] - 0s 750us/step - loss: 1170.2064
# Epoch 194/200
# 16/16 [==============================] - 0s 625us/step - loss: 1154.1802
# Epoch 195/200
# 16/16 [==============================] - 0s 687us/step - loss: 1126.9982
# Epoch 196/200
# 16/16 [==============================] - 0s 750us/step - loss: 1117.7301
# Epoch 197/200
# 16/16 [==============================] - 0s 812us/step - loss: 1119.0625
# Epoch 198/200
# 16/16 [==============================] - 0s 750us/step - loss: 1129.2709
# Epoch 199/200
# 16/16 [==============================] - 0s 750us/step - loss: 1126.7137
# Epoch 200/200
# 16/16 [==============================] - 0s 750us/step - loss: 1132.3230

# %% [markdown]
# ### Prediction
# Returning the predicted power produced from windspeed 20.

# %%
test.Predictions()
# Out:
# Power prediction: 89.844
# Power prediction: 85.715

# %% [markdown]
# ### Display Loss
# Displaying the loss from the Linear regression and polynomial regression models.

# %%
test.DisplayLoss()

# %% [markdown]
# ### Displaying Predictions
# Displaying the predictions from the Linear regression and polynomial regression models.

# %%
test.DisplayPredictions()
